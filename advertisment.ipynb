# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
x=df.iloc[:,:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
# seaborn

import seaborn as sns
sns.regplot(x=df['TV'],y=y,color='r')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.regplot(x=df['Radio'],y=y,color='b')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.regplot(x=df['Newspaper'],y=y,color='g')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#         TV  Radio  Newspaper
# 116  139.2   14.3       25.6
# 67   139.3   14.5       10.2
# 78     5.4   29.9        9.4
# 42   293.6   27.7        1.8
# 17   281.4   39.6       55.8
# ..     ...    ...        ...
# 133  219.8   33.5       45.1
# 137  273.7   28.9       59.7
# 72    26.8   33.0       19.3
# 140   73.4   17.0       12.9
# 37    74.7   49.4       45.7
#
# [140 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([21.28816103, 18.04213212, 10.0595901 , 21.08224067, 20.76476044,
#        24.47187353, 16.80643646, 15.62885738, 10.12479884, 18.84601896,
#        15.78389695, 10.54297035, 18.92928707, 15.52557996, 17.8412711 ,
#        15.24120343, 13.74212833, 21.0643733 , 10.05392699, 19.26500889,
#        11.16451173, 11.97211832,  8.61179009, 11.98972141, 12.59914023,
#        16.8447954 ,  9.7170889 , 21.09489946, 18.13942474, 19.55008709,
#        22.08796224, 17.78527998, 16.53883452, 14.77303861, 21.39458945,
#        16.95491635, 17.22755002, 12.31866943, 21.04982199,  7.77473926,
#         5.38467516,  9.63139004,  6.89549204, 19.19507436,  7.88125192,
#        15.18766673, 13.70978421, 21.0232936 , 20.5350058 , 20.48867548,
#        24.86087902, 14.96304281,  7.33545571, 19.35630325, 21.32554066,
#        14.7719757 , 17.19642519,  7.11988693, 18.30096543,  9.65158222])

# %%
print(model.predict([[210,34,50]]))
# Out:
# [19.62644808]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df1=pd.DataFrame({'Actual value':y_test,'Predicted value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#      Actual value  Predicted value  Difference
# 58           23.8        21.288161    2.511839
# 40           16.6        18.042132   -1.442132
# 34           11.9        10.059590    1.840410
# 102          19.8        21.082241   -1.282241
# 184          17.6        20.764760   -3.164760
# 198          25.5        24.471874    1.028126
# 95           16.9        16.806436    0.093564
# 4            17.9        15.628857    2.271143
# 29           10.5        10.124799    0.375201
# 168          17.1        18.846019   -1.746019
# 171          17.5        15.783897    1.716103
# 18           11.3        10.542970    0.757030
# 11           17.4        18.929287   -1.529287
# 89           16.7        15.525580    1.174420
# 110          18.4        17.841271    0.558729
# 118          15.9        15.241203    0.658797
# 159          12.9        13.742128   -0.842128
# 35           17.8        21.064373   -3.264373
# 136           9.5        10.053927   -0.553927
# ...

# %%
print('slope is:')
list(zip(x,model.coef_))                  #   zip  : means combine
# print('slope is:',x[model.coef_])
# Out:
# slope is:
# [('TV', 0.05502391767315305),
#  ('Radio', 0.10251002697521279),
#  ('Newspaper', -0.0015071052925105383)]

# %%
print('constant is:',model.intercept_)
# Out:
# constant is: 4.661439720130817

# %%
from sklearn.metrics import mean_absolute_error
print('MSE:',mean_absolute_error(y_test,y_pred))
# Out:
# MSE: 1.194741713405674

# %%
from sklearn.metrics import mean_absolute_percentage_error
print('MAPE is:',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# MAPE is: 0.0769508078872673

# %%
from sklearn.metrics import mean_squared_error,r2_score
RMSE=mean_squared_error(y_test,y_pred)
print('MSE is:',RMSE)
print('RMSE is:',np.sqrt(RMSE))
print('r2_score is:',r2_score(y_test,y_pred))
# Out:
# MSE is: 2.370659971225658
# RMSE is: 1.5396947656031237
# r2_score is: 0.9071151423684273
