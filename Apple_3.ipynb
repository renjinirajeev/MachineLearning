# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/apple_quality.csv')
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
df.tail()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
df.isna().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
df.drop(['A_id'],axis=1,inplace=True)
df.isna().sum()
# Out:
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
df['Size']=df['Size'].fillna(df['Size'].mean())
df['Weight']=df['Weight'].fillna(df['Weight'].mean())
df['Sweetness']=df['Sweetness'].fillna(df['Sweetness'].mean())
df['Crunchiness']=df['Crunchiness'].fillna(df['Crunchiness'].mean())
df['Juiciness']=df['Juiciness'].fillna(df['Juiciness'].mean())
df['Ripeness']=df['Ripeness'].fillna(df['Ripeness'].mean())
df['Quality']=df['Quality'].fillna(df['Quality'].mode()[0])
df.isna().sum()
# Out:
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
df.dtypes
# Out:
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity         object
# Quality         object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Acidity']=lb.fit_transform(df['Acidity'])
df.dtypes
# Out:
# Size           float64
# Weight         float64
# Sweetness      float64
# Crunchiness    float64
# Juiciness      float64
# Ripeness       float64
# Acidity          int64
# Quality         object
# dtype: object

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[-3.97004852e+00, -2.51233638e+00,  5.34632961e+00, ...,
#          1.84490036e+00,  3.29839797e-01,  3.97000000e+02],
#        [-1.19521719e+00, -2.83925653e+00,  3.66405876e+00, ...,
#          8.53285795e-01,  8.67530082e-01,  5.50000000e+02],
#        [-2.92023862e-01, -1.35128199e+00, -1.73842916e+00, ...,
#          2.83863551e+00, -3.80333280e-02,  3.54300000e+03],
#        ...,
#        [-4.00800374e+00, -1.77933711e+00,  2.36639697e+00, ...,
#          2.16143512e+00,  2.14488384e-01,  1.42800000e+03],
#        [ 2.78539650e-01, -1.71550503e+00,  1.21217251e-01, ...,
#          1.26667740e+00, -7.76571470e-01,  3.04100000e+03],
#        [-5.03014630e-01, -9.89546545e-01, -4.70478520e-01, ...,
#          5.12117968e-01,  4.98277428e-01,  4.00000000e+03]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['good', 'good', 'bad', ..., 'good', 'good', 'good'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[-1.54241097e+00, -9.42480815e-01, -5.08999257e-01, ...,
#         -8.19818136e-01,  8.48231585e-01,  2.64800000e+03],
#        [ 2.94586351e-01, -3.53755252e-01, -5.40281839e-01, ...,
#          6.71989996e-01,  1.29183819e+00,  2.63100000e+03],
#        [-5.14301592e-01, -2.78214336e+00,  3.14528232e+00, ...,
#          9.31536359e-01,  1.03334310e+00,  3.61000000e+02],
#        ...,
#        [-2.49258269e+00, -2.06591657e+00,  1.08117994e+00, ...,
#         -1.60072238e+00, -2.83194749e+00,  2.43300000e+03],
#        [-4.98846599e+00, -1.90696332e-01,  3.45144007e+00, ...,
#          1.72614427e+00, -8.59105780e-02,  1.24900000e+03],
#        [-6.09625194e-01, -1.74773411e+00,  9.44680078e-01, ...,
#         -3.97477816e-01,  1.17733095e+00,  3.17200000e+03]])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_train
# Out:
# array([[-5.33426131e-01,  3.34940029e-02, -1.99475122e-02, ...,
#         -7.00386586e-01,  1.81866889e-01,  5.48144125e-01],
#        [ 4.17764445e-01,  3.98328683e-01, -3.60285266e-02, ...,
#          7.52888278e-02,  4.19112774e-01,  5.33422760e-01],
#        [-1.07480955e-03, -1.10654940e+00,  1.85855966e+00, ...,
#          2.10241660e-01,  2.80866644e-01, -1.43231236e+00],
#        ...,
#        [-1.02542162e+00, -6.62701895e-01,  7.97494430e-01, ...,
#         -1.10642286e+00, -1.78633498e+00,  3.61962164e-01],
#        [-2.31778097e+00,  4.99376697e-01,  2.01594204e+00, ...,
#          6.23403248e-01, -3.17723026e-01, -6.63337563e-01],
#        [-5.04330263e-02, -4.65523443e-01,  7.27325790e-01, ...,
#         -4.80787969e-01,  3.57872993e-01,  1.00190853e+00]])

# %%
 x_test
# Out:
# array([[-0.35278807, -0.30242691, -0.62334813, ...,  0.70771549,
#          0.46068   ,  0.9170442 ],
#        [-0.4485167 , -0.06131069,  1.03995353, ...,  0.61314183,
#         -0.3469767 , -0.86424089],
#        [-0.26473671, -0.46429423,  0.94572135, ..., -0.46910106,
#          0.11768323, -0.74214016],
#        ...,
#        [ 0.31647758, -0.33311134,  0.03409034, ..., -0.20235772,
#         -1.6324375 ,  0.14980133],
#        [ 0.53789313, -0.2209421 , -2.28579744, ..., -0.09431912,
#          1.19419279, -1.68690537],
#        [-0.24863702, -0.65981899, -0.9512285 , ...,  1.63149587,
#          1.63951247, -1.61936028]])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
knn=KNeighborsClassifier(n_neighbors=7)
base=GaussianNB()
model=SVC()
lst=[knn,base,model]

# %%
for i in lst:
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print('Model is:',i)
  print(y_pred)
  print('*'*100)
  print('score is:',accuracy_score(y_test,y_pred))
  print('*'*100)
  print(confusion_matrix(y_test,y_pred))
  print('*'*100)
  print('classification report:')
  print(classification_report(y_test,y_pred))
# Out:
# Model is: KNeighborsClassifier(n_neighbors=7)
# ['bad' 'good' 'bad' ... 'good' 'bad' 'bad']
# ****************************************************************************************************
# score is: 0.8884263114071607
# ****************************************************************************************************
# [[543  67]
#  [ 67 524]]
# ****************************************************************************************************
# classification report:
#               precision    recall  f1-score   support
#
#          bad       0.89      0.89      0.89       610
#         good       0.89      0.89      0.89       591
#
#     accuracy                           0.89      1201
#    macro avg       0.89      0.89      0.89      1201
# weighted avg       0.89      0.89      0.89      1201
#
# Model is: GaussianNB()
# ['bad' 'good' 'bad' ... 'good' 'bad' 'bad']
# ****************************************************************************************************
# score is: 0.7668609492089925
# ****************************************************************************************************
# [[464 146]
#  [134 457]]
# ****************************************************************************************************
# classification report:
#               precision    recall  f1-score   support
#
#          bad       0.78      0.76      0.77       610
#         good       0.76      0.77      0.77       591
#
#     accuracy                           0.77      1201
#    macro avg       0.77      0.77      0.77      1201
# weighted avg       0.77      0.77      0.77      1201
#
# Model is: SVC()
# ['bad' 'good' 'good' ... 'good' 'bad' 'bad']
# ****************************************************************************************************
# score is: 0.8834304746044963
# ****************************************************************************************************
# [[534  76]
#  [ 64 527]]
# ****************************************************************************************************
# classification report:
#               precision    recall  f1-score   support
#
#          bad       0.89      0.88      0.88       610
#         good       0.87      0.89      0.88       591
#
#     accuracy                           0.88      1201
#    macro avg       0.88      0.88      0.88      1201
# weighted avg       0.88      0.88      0.88      1201
