# %%
import numpy as np
import matplotlib.pyplot as plt

x=[2600,3000,3200,3600,4000]
y=[5500000,6100000,6250000,6800000,7100000]
plt.scatter(x,y)
plt.xlabel('AREA')
plt.ylabel('PRICE')
plt.title('Area Vs Price')
# Out:
# Text(0.5, 1.0, 'Area Vs Price')
