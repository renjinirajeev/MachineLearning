# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/data.csv')
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
df.dtypes
# Out:
# Height    float64
# Weight    float64
# dtype: object

# %%
x=df.iloc[:,:-1]
x
# Out:
#     Height
# 0     1.47
# 1     1.50
# 2     1.52
# 3     1.55
# 4     1.57
# 5     1.60
# 6     1.63
# 7     1.65
# 8     1.68
# 9     1.70
# 10    1.73
# 11    1.75
# 12    1.78
# 13    1.80
# 14    1.83

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     52.21
# 1     53.12
# 2     54.48
# 3     55.84
# 4     57.20
# 5     58.57
# 6     59.93
# 7     61.29
# 8     63.11
# 9     64.47
# 10    66.28
# 11    68.10
# 12    69.92
# 13    72.19
# 14    74.46
# Name: Weight, dtype: float64

# %%
plt.scatter(x,y,color='r')
plt.xlabel('Height in Inches')
plt.ylabel('Weight in Pounds')
plt.title('Height Vs Weight Graph')
# Out:
# Text(0.5, 1.0, 'Height Vs Weight Graph')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=2)
x_train
# Out:
#     Height
# 3     1.55
# 1     1.50
# 10    1.73
# 7     1.65
# 12    1.78
# 2     1.52
# 6     1.63
# 14    1.83
# 13    1.80
# 8     1.68

# %%
x_test
# Out:
#     Height
# 11    1.75
# 4     1.57
# 5     1.60
# 0     1.47
# 9     1.70

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([68.3070915 , 56.93219427, 58.82801048, 50.61280692, 65.14739783])

# %%
print(model.predict([[2.5]]))
# Out:
# [115.70249663]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='r')
plt.plot(x_test,y_pred,color='g')

# %%
df1=pd.DataFrame({'Actual value':y_test,'Predicted_value':y_pred,'Ddifference':y_test-y_pred})
df1
# Out:
#     Actual value  Predicted_value  Ddifference
# 11         68.10        68.307092    -0.207092
# 4          57.20        56.932194     0.267806
# 5          58.57        58.828010    -0.258010
# 0          52.21        50.612807     1.597193
# 9          64.47        65.147398    -0.677398

# %%
print('slope is:',model.coef_)
# Out:
# slope is: [63.1938735]

# %%
print('Constant is:',model.intercept_)
# Out:
# Constant is: -42.28218712800579

# %%
from sklearn.metrics import mean_absolute_error
print('MAE is:',mean_absolute_error(y_test,y_pred))
# Out:
# MAE is: 0.6014997222442673

# %%
from sklearn.metrics import mean_absolute_percentage_error
print('MAPE is:',mean_absolute_percentage_error(y_test,y_pred))
# Out:
# MAPE is: 0.010645392183944691

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:',mean_squared_error(y_test,y_pred))
# Out:
# MSE is: 0.6382139505042559

# %%
RMSE=np.sqrt(mean_squared_error(y_test,y_pred))
print('RMSE is:',RMSE)
# Out:
# RMSE is: 0.7988829391746052

# %%
from sklearn.metrics import r2_score
print('R2 score is:',r2_score(y_test,y_pred))
# Out:
# R2 score is: 0.9795574502366999
